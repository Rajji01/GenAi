# %%
# !pip install nltk
import nltk
nltk.download('punkt')
# Out:
# Requirement already satisfied: nltk in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from nltk) (2024.4.16)
# Requirement already satisfied: joblib in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: tqdm in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from click->nltk) (6.7.0)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from importlib-metadata; python_version < "3.8"->click->nltk) (3.15.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from importlib-metadata; python_version < "3.8"->click->nltk) (4.7.1)
# WARNING: You are using pip version 20.1.1; however, version 24.0 is available.
# You should consider upgrading via the 'c:\users\lenovo\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
corpus=""""Hello welcome, to rajat Agrawal NLP tutorial.
Please do watch the entire course ! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
# "Hello welcome, to rajat Agrawal NLP tutorial.
# Please do watch the entire course ! to become expert in NLP.

# %%
#sentence into para
from nltk.tokenize import sent_tokenize
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# "Hello welcome, to rajat Agrawal NLP tutorial.
# Please do watch the entire course !
# to become expert in NLP.

# %%
## tokenization para-> words sentence-->words
from nltk.tokenize import word_tokenize
word_tokenize(corpus)
# Out:
# ['``',
#  'Hello',
#  'welcome',
#  ',',
#  'to',
#  'rajat',
#  'Agrawal',
#  'NLP',
#  'tutorial',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['``', 'Hello', 'welcome', ',', 'to', 'rajat', 'Agrawal', 'NLP', 'tutorial', '.']
# ['Please', 'do', 'watch', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)
# Out:
# ['"',
#  'Hello',
#  'welcome',
#  ',',
#  'to',
#  'rajat',
#  'Agrawal',
#  'NLP',
#  'tutorial',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['``',
#  'Hello',
#  'welcome',
#  ',',
#  'to',
#  'rajat',
#  'Agrawal',
#  'NLP',
#  'tutorial.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
